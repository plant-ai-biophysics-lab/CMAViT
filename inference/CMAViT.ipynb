# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import Inference as inf

# %%
EXTREME_LOWER_THRESHOLD = 22.24
EXTREME_UPPER_THRESHOLD = 54.36

# %% [markdown]
# ### S2-Mngm

# %%
E000 = '000_s2text_vit_768_8_6_6_30_0001_01_32_init01_ts'
Ex_000 = inf.performance(E000)
Ex_000.scatter_plot()

# %%
Ex_000.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Ex_000.mape_per_yield_range(th1 = EXTREME_LOWER_THRESHOLD, 
                            th2 = EXTREME_UPPER_THRESHOLD)
# Out:
# All: MAE = 3.99, MAPE = 12.61 | C1: MAE = 5.01, MAPE = 26.59 | C2: MAE = 3.61, MAPE = 11.21 | C3: MAE = 9.02, MAPE = 14.76
# ...

# %% [markdown]
# ### S2-Mngm-CSR

# %%
E001 = '001_s2text_vit_768_8_6_6_30_0001_01_32_init01_ts_csr'
Ex_001 = inf.performance(E001)
Ex_001.scatter_plot()

# %%
Ex_001.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Ex_001.mape_per_yield_range(th1 = EXTREME_LOWER_THRESHOLD, 
                            th2 = EXTREME_UPPER_THRESHOLD)
# Out:
# All: MAE = 3.49, MAPE = 11.00 | C1: MAE = 3.32, MAPE = 17.76 | C2: MAE = 3.28, MAPE = 10.32 | C3: MAE = 7.49, MAPE = 12.27
# ...

# %% [markdown]
# ### S12-Mngm

# %%
E002 = '002_s12text_vit_768_8_6_8_30_0001_01_32_init01_ts'
Ex_002 = inf.performance(E002)
Ex_002.scatter_plot()

# %%
Ex_002.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Ex_002.mape_per_yield_range(th1 = EXTREME_LOWER_THRESHOLD, 
                            th2 = EXTREME_UPPER_THRESHOLD)
# Out:
# All: MAE = 3.73, MAPE = 11.48 | C1: MAE = 3.19, MAPE = 16.94 | C2: MAE = 3.46, MAPE = 10.76 | C3: MAE = 9.45, MAPE = 15.54
# ...

# %% [markdown]
# ### Full

# %%
E003 = '003_full_vit_768_8_6_8_30_0001_01_32_init01_ts'
Ex_003 = inf.performance(E003)
Ex_003.scatter_plot()

# %%
Ex_003.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Ex_003.mape_per_yield_range(th1 = EXTREME_LOWER_THRESHOLD, 
                            th2 = EXTREME_UPPER_THRESHOLD)
# Out:
# All: MAE = 3.29, MAPE = 10.19 | C1: MAE = 2.90, MAPE = 15.61 | C2: MAE = 3.06, MAPE = 9.52 | C3: MAE = 8.09, MAPE = 13.35
# ...

# %% [markdown]
# ### Full-CSR

# %%
E004 = '004_full_vit_768_8_6_8_30_0001_01_32_init01_csr'
Ex_004 = inf.performance(E004)
Ex_004.scatter_plot()

# %%
Ex_004.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Ex_004.mape_per_yield_range(th1 = EXTREME_LOWER_THRESHOLD, 
                            th2 = EXTREME_UPPER_THRESHOLD)
# Out:
# All: MAE = 2.77, MAPE = 8.22 | C1: MAE = 1.87, MAPE = 10.25 | C2: MAE = 2.75, MAPE = 8.08 | C3: MAE = 4.52, MAPE = 7.42
# ...

# %% [markdown]
# ### Full - YZ

# %%
E010 = '010_full_vit_768_8_6_8_30_0001_01_32_init01_yz'
Ex_010 = inf.performance(E010)
Ex_010.scatter_plot()

# %%
Ex_010.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Ex_010.mape_per_yield_range(th1 = EXTREME_LOWER_THRESHOLD, 
                            th2 = EXTREME_UPPER_THRESHOLD)
# Out:
# All: MAE = 1.52, MAPE = 4.54 | C1: MAE = 1.57, MAPE = 8.78 | C2: MAE = 1.26, MAPE = 3.86 | C3: MAE = 6.09, MAPE = 9.92
# ...

# %% [markdown]
# ## All models

# %%
inf.multi_model_timeseries_plot().plot()

# %% [markdown]
# ## Maskout Results

# %% [markdown]
# ### TextMaskout

# %%
E005 = '005_s12met_vit_768_8_6_8_30_0001_01_64_init01_text_maskout'
Ex_005 = inf.performance(E005)
Ex_005.scatter_plot()

# %% [markdown]
# ### Met Maskout

# %%
E006 = '006_s12text_vit_768_8_6_8_30_0001_01_64_init01_met_maskout'
Ex_006 = inf.performance(E006)
Ex_006.scatter_plot()

# %% [markdown]
# ### Climate + Text Maskout

# %%
E007 = '007_s12_vit_768_8_6_8_30_0001_01_64_init01_mettext_maskout'
Ex_007 = inf.performance(E007)
Ex_007.scatter_plot()
