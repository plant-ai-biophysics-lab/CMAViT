# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
import Inference as inf

# %% [markdown]
# ### Sentinel2 & Text

# %%
E002 = '000_s2text_vit_768_8_6_6_30_0001_01_64_init01'
Ex_002 = inf.performance(E002)
Ex_002.scatter_plot()

# %% [markdown]
# ### Sentinel 1-2 & text

# %%
E002 = '001_s12text_vit_768_8_6_8_30_0001_01_64_init01'
Ex_002 = inf.performance(E002)
Ex_002.scatter_plot()

# %% [markdown]
# ### Sentinel 1-2 & Meteorology & text

# %%
E003 = '002_s12mettext_vit_768_8_6_8_30_0001_01_64_init01'
Ex_003 = inf.performance(E003)
Ex_003.scatter_plot()

# %% [markdown]
# ### Sentinel 1-2 & Meteorology & text & CSR

# %%
E007 = '007_s12mettext_vit_769_8_6_8_30_0001_01_64_init01_csr'
Ex_007 = inf.performance(E007)
Ex_007.scatter_plot()
