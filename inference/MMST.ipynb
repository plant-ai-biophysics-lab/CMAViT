# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
# import sys
# sys.path.append('../')
# from src import utils, RWSampler
import Inference as inf

# %%
MIN_EXTREME_VALUE_Threshold = 22.24
Max_EXTREME_VALUE_Threshold = 54.36

# %% [markdown]
# ### LRP

# %%
LRP = '07_MMST_LRP'
Ex_LRP = inf.performance(LRP)

# %%
Ex_LRP.scatter_plot()

# %%
Ex_LRP.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Ex S2 + Met + Text

# %%
N02 = '02_MMST_S2S1MT_0001_01_8_6_768_30_64_MSE_resampling'
Ex02 = inf.performance(N02)

# %%
Ex02.scatter_plot()

# %%
Ex02.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
N04 = '04_MMST_S2S1M_0001_09_8_6_768_30_64_MSE_resampling'
Ex04 = inf.performance(N04)

# %%
Ex04.scatter_plot()

# %%
N05 = '05_MMST_S2S1T_0001_09_8_6_768_30_64_MSE_resampling'
Ex05 = inf.performance(N05)

# %%
Ex05.scatter_plot()

# %% [markdown]
# ### Ex00: Image_Met_Text_YZ

# %%
exp_name = '00_IMTYZ_0001_0001_8_6_768_10_64_MSE'
Ex00= inf.performance(exp_name)

# %%
Ex00.scatter_plot()

# %% [markdown]
# ### Ex 07: Image_Met_YZ

# %%
exp_name = '07_MMST_IMG_MET_YZ_0001_0001'
Ex07= inf.performance(exp_name)

# %%
Ex07.scatter_plot()

# %%
Ex07.time_series_plot()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#      weeks   R2_mean  MAE_mean  RMSE_mean  MAPE_mean
# 0   Apr 01  0.929920  1.955141   2.605133   5.948372
# 1   Apr 08  0.937265  1.851084   2.464830   5.651993
# 2   Apr 17  0.934926  1.899916   2.510364   5.774238
# 3   Apr 26  0.936323  1.862988   2.483260   5.637711
# 4   May 05  0.936817  1.864052   2.473610   5.633413
# 5   May 15  0.939648  1.827583   2.417565   5.539040
# 6   May 21  0.942154  1.790856   2.366835   5.437275
# 7   May 30  0.942668  1.784669   2.356309   5.411072
# 8   Jun 10  0.944119  1.760714   2.326299   5.352369
# 9   Jun 16  0.944792  1.754173   2.312236   5.342324
# 10  Jun 21  0.944555  1.770671   2.317206   5.405147
# 11  Jun 27  0.944493  1.764078   2.318494   5.372032
# 12  Jul 02  0.945597  1.739310   2.295330   5.296884
# 13  Jul 09  0.945473  1.742069   2.297940   5.305062
# ...
