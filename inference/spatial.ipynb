# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../')
import Inference as inf

# %%
MIN_EXTREME_VALUE_Threshold = 22.24
Max_EXTREME_VALUE_Threshold = 54.36

# %% [markdown]
# ### S2-Mngm

# %%
Ex000 = inf.timeseries_spatial_variability(exp_name= '000_s2text_vit_768_8_6_6_30_0001_01_32_init01_ts')

# %%
_ = Ex000.plot(block_name = 178, year = 2016, min_v = 20, max_v = 55)

# %%
_ = Ex000.plot(block_name = 178, year = 2017, min_v = 30, max_v = 55)

# %%
_ = Ex000.plot(block_name = 178, year = 2018, min_v = 30, max_v = 55)

# %%
_ = Ex000.plot(block_name = 178, year = 2019, min_v = 30, max_v = 55)

# %%
_ = Ex000.plot(block_name = 25, year = 2019, min_v = 15, max_v = 35)

# %%
_ = Ex000.plot(block_name = 105, year = 2018, min_v = 35, max_v = 65)

# %%
_ = Ex000.plot(block_name = 181, year = 2019, min_v = 45, max_v = 65)

# %%
_ = Ex000.plot(block_name = 186, year = 2017, min_v = 15, max_v = 55)

# %% [markdown]
# ### S2-Mngm-CSR

# %%
Ex001 = inf.timeseries_spatial_variability(exp_name= '001_s2text_vit_768_8_6_6_30_0001_01_32_init01_ts_csr')

# %%
_ = Ex001.plot(block_name = 178, year = 2016, min_v = 20, max_v = 55)

# %%
_ = Ex001.plot(block_name = 178, year = 2017, min_v = 30, max_v = 55)

# %%
_ = Ex001.plot(block_name = 178, year = 2018, min_v = 30, max_v = 55)

# %%
_ = Ex001.plot(block_name = 178, year = 2019, min_v = 30, max_v = 55)

# %%
_ = Ex001.plot(block_name = 25, year = 2019, min_v = 15, max_v = 35)

# %%
_ = Ex001.plot(block_name = 105, year = 2018, min_v = 35, max_v = 65)

# %%
_ = Ex001.plot(block_name = 181, year = 2019, min_v = 45, max_v = 65)

# %%
_ = Ex001.plot(block_name = 186, year = 2017, min_v = 15, max_v = 55)

# %% [markdown]
# ### S12-Mngm

# %%
Ex002 = inf.timeseries_spatial_variability(exp_name= '002_s12text_vit_768_8_6_8_30_0001_01_32_init01_ts')

# %%
_ = Ex002.plot(block_name = 178, year = 2016, min_v = 20, max_v = 55)

# %%
_ = Ex002.plot(block_name = 178, year = 2017, min_v = 30, max_v = 55)

# %%
_ = Ex002.plot(block_name = 178, year = 2018, min_v = 30, max_v = 55)

# %%
_ = Ex002.plot(block_name = 178, year = 2019, min_v = 30, max_v = 55)

# %%
_ = Ex002.plot(block_name = 25, year = 2019, min_v = 15, max_v = 35)

# %%
_ = Ex002.plot(block_name = 105, year = 2018, min_v = 35, max_v = 65)

# %%
_ = Ex002.plot(block_name = 181, year = 2019, min_v = 45, max_v = 65)

# %%
_ = Ex002.plot(block_name = 186, year = 2017, min_v = 15, max_v = 55)

# %% [markdown]
# ### Full

# %%
Ex003 = inf.timeseries_spatial_variability(exp_name= '003_full_vit_768_8_6_8_30_0001_01_32_init01_ts')

# %%
_ = Ex003.plot(block_name = 178, year = 2016, min_v = 20, max_v = 55)

# %%
_ = Ex003.plot(block_name = 178, year = 2017, min_v = 30, max_v = 55)

# %%
_ = Ex003.plot(block_name = 178, year = 2018, min_v = 30, max_v = 55)

# %%
_ = Ex003.plot(block_name = 178, year = 2019, min_v = 30, max_v = 55)

# %%
_ = Ex003.plot(block_name = 25, year = 2019, min_v = 15, max_v = 35)

# %%
_ = Ex003.plot(block_name = 105, year = 2018, min_v = 35, max_v = 65)

# %%
_ = Ex003.plot(block_name = 181, year = 2019, min_v = 45, max_v = 65)

# %%
_ = Ex003.plot(block_name = 186, year = 2017, min_v = 15, max_v = 55)

# %% [markdown]
# ### Full -CSR

# %%
Ex004 = inf.timeseries_spatial_variability(exp_name= '004_full_vit_768_8_6_8_30_0001_01_32_init01_csr')

# %%
_ = Ex004.plot(block_name = 178, year = 2016, min_v = 20, max_v = 55)

# %%
_ = Ex004.plot(block_name = 178, year = 2017, min_v = 30, max_v = 55)

# %%
_ = Ex004.plot(block_name = 178, year = 2018, min_v = 30, max_v = 55)

# %%
_ = Ex004.plot(block_name = 178, year = 2019, min_v = 30, max_v = 55)

# %%
_ = Ex004.plot(block_name = 25, year = 2019, min_v = 15, max_v = 35)

# %%
_ = Ex004.plot(block_name = 105, year = 2018, min_v = 35, max_v = 65)

# %%
_ = Ex004.plot(block_name = 181, year = 2019, min_v = 45, max_v = 65)

# %%
_ = Ex004.plot(block_name = 186, year = 2017, min_v = 15, max_v = 55)

# %% [markdown]
# ### Full YZ

# %%
Ex005 = inf.timeseries_spatial_variability(exp_name= '010_full_vit_768_8_6_8_30_0001_01_32_init01_yz')

# %%
_ = Ex005.plot(block_name = 178, year = 2016, min_v = 20, max_v = 55)

# %%
_ = Ex005.plot(block_name = 178, year = 2017, min_v = 30, max_v = 55)

# %%
_ = Ex005.plot(block_name = 178, year = 2018, min_v = 30, max_v = 55)

# %%
_ = Ex005.plot(block_name = 178, year = 2019, min_v = 30, max_v = 55)

# %%
_ = Ex005.plot(block_name = 25, year = 2019, min_v = 15, max_v = 35)

# %%
_ = Ex005.plot(block_name = 105, year = 2018, min_v = 35, max_v = 65)

# %%
_ = Ex005.plot(block_name = 181, year = 2019, min_v = 45, max_v = 65)

# %%
_ = Ex005.plot(block_name = 186, year = 2017, min_v = 15, max_v = 55)
